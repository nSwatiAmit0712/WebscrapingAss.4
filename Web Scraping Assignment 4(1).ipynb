# %%
# selenium
import selenium
import pandas as pd
from selenium import webdriver

# Beautiful soup
from bs4 import BeautifulSoup
import requests

import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException,ElementNotInteractableException
from selenium.webdriver.common.by import By
from time import sleep

# %% [markdown]
# # Q.1.

# %%
driver=webdriver.Chrome(r"C:\Users\Swati\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
Rank = []
Name = []
Artist = []
Date = []
Views = []

# %%
# scraping Rank of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")
        
# Scraping Name of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")
        
# Scraping Artist of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]"):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("-")
        
# Scraping Upload_Date of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]"):
        Date.append(i.text)
except NoSuchElementException:
    Date.append("-")
        
# Scraping Views of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("-")
        
# creating DataFrame for scraped data
Wiki = pd.DataFrame({})
Wiki['Rank'] = Rank
Wiki['Name'] = Name
Wiki['Artist'] = Artist
Wiki['Upload Date'] = Date
Wiki['Views (in Billions)'] = Views

# removing stray numbers from Name column
Wiki.Name = Wiki.Name.apply(lambda x:x[:-4].strip('"'))
Wiki
# Out:
#    Rank                                       Name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                               Shape of You
# 4    5.                              See You Again
# 5    6.                                  Bath Song
# 6    7.                Phonics Song with Two Words
# 7    8.                                Uptown Funk
# 8    9.  Learning Colors – Colorful Eggs on a Farm
# 9   10.                              Gangnam Style
# 10  11.   Masha and the Bear – Recipe for Disaster
# 11  12.                          Wheels on the Bus
# 12  13.                             Dame Tu Cosita
# 13  14.                                      Sugar
# 14  15.                                       Roar
# 15  16.                             Counting Stars
# 16  17.                                      Sorry
# 17  18.                                     Axel F
# 18  18.                          Thinking Out Loud
# 19  20.                        Baa Baa Black Sheep
# 20  21.                                 Dark Horse
# 21  22.                                      Faded
# 22  23.                             Girls Like You
# 23  24.                                 Let Her Go
# 24  25.                                   Bailando
# 25  26.                                    Lean On
# 26  27.                                    Perfect
# 27  28.           Waka Waka (This Time for Africa)
# 28  29.                               Shake It Off
# 29  30.          Humpty the train on a fruits ride
#
#                                            Artist        Upload Date  \
# 0     Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                      Luis Fonsi   January 12, 2017
# 2                                     LooLoo Kids    October 8, 2016
# 3                                      Ed Sheeran   January 30, 2017
# 4                                     Wiz Khalifa      April 6, 2015
# 5                      Cocomelon – Nursery Rhymes        May 2, 2018
# 6                                       ChuChu TV      March 6, 2014
# 7                                     Mark Ronson  November 19, 2014
# 8                                     Miroshka TV  February 27, 2018
# 9                                             Psy      July 15, 2012
# 10                                     Get Movies   January 31, 2012
# 11                     Cocomelon – Nursery Rhymes       May 24, 2018
# 12                                      El Chombo      April 5, 2018
# 13                                       Maroon 5   January 14, 2015
# 14                                     Katy Perry  September 5, 2013
# 15                                    OneRepublic       May 31, 2013
# 16                                  Justin Bieber   October 22, 2015
# 17                                     Crazy Frog      June 16, 2009
# 18                                     Ed Sheeran    October 7, 2014
# 19                     Cocomelon – Nursery Rhymes      June 25, 2018
# 20                                     Katy Perry  February 20, 2014
# 21                                    Alan Walker   December 3, 2015
# 22                                       Maroon 5       May 31, 2018
# 23                                      Passenger      July 25, 2012
# 24                               Enrique Iglesias     April 11, 2014
# 25                                    Major Lazer     March 22, 2015
# 26                                     Ed Sheeran   November 9, 2017
# 27                                        Shakira       June 4, 2010
# 28                                   Taylor Swift    August 18, 2014
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs   January 26, 2018
#
#    Views (in Billions)
# 0                11.40
# 1                 7.98
# 2                 6.47
# 3                 5.81
# 4                 5.64
# 5                 5.63
# 6                 4.90
# 7                 4.70
# 8                 4.65
# 9                 4.55
# 10                4.51
# 11                4.40
# 12                4.07
# 13                3.76
# 14                3.66
# 15                3.65
# 16                3.59
# 17                3.52
# 18                3.50
# 19                3.38
# 20                3.35
# 21                3.34
# 22                3.33
# 23                3.30
# 24                3.27
# 25                3.26
# 26                3.26
# 27                3.25
# 28                3.21
# 29                3.17

# %% [markdown]
# # Q.2.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url=('https://www.bcci.tv/')
driver.get(url)
sleep(2)

# %%
btn=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a').click()
sleep(3)

# creating empty lists for scraping the data
Match = []
Series = []
Place = []
Date = []
Time = []

# %%
match = driver.find_elements(By.XPATH,"//div[@class='fixture__format-strip']/span[@class='u-unskewed-text fixture__format']")
for i in match:
    Match.append(i.text)

sleep(2)
series = driver.find_elements(By.XPATH,"//div[@class='fixture__format-strip']/span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in series:
    Series.append(i.text)
sleep(2)
    
place = driver.find_elements(By.XPATH,"//div[@class='fixture__description u-unskewed-text']/p/span")
for i in place:
    Place.append(i.text)
sleep(2)
    
date = driver.find_elements(By.XPATH,"//span[@class='fixture__datetime tablet-only']/strong[1]")
for i in date:
    Date.append(i.text)
sleep(2)
    
date=[i.split(' ',3)[:3] for i in Date]
date=[' '.join(i) for i in date]
Time=[i.split(' ',3)[-1] for i in Date]
sleep(2)

# %%
len(Match)
# Out:
# 0

# %%
# creating data frame
fixture=pd.DataFrame({'Match Title': Match,
                          "Series": Series,
                          "Place": Place,
                          "Date": date,
                          "Time": Time})
fixture
# Out:
# Empty DataFrame
# Columns: [Match Title, Series, Place, Date, Time]
# Index: []

# %% [markdown]
# # Q.3.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url = ("https://www.guru99.com/")
driver.get(url)
sleep(2)

# %%
Name = []
Description = []

# %%
# clicking on Selenium button
driver.find_element(By.XPATH,"//li//a[@title='Selenium']").click()
sleep(1)

# clicking on Exception Handling button
driver.find_element(By.XPATH,'//a[@title="Selenium Exception Handling (Common Exceptions List)"]').click()
sleep(1)

# scraping Name
for i in driver.find_elements(By.XPATH,"//table[@class='table table-striped']/tbody/tr/td[1]"):
    Name.append(i.text)
sleep(1)
    
# scraping Description
for i in driver.find_elements(By.XPATH,"//table[@class='table table-striped']/tbody/tr/td[2]"):
    Description.append(i.text)
sleep(1)

    
# creating the dataframe from the scraped data
Selenium = pd.DataFrame({})
Selenium['Exception_Name'] = Name
Selenium['Description'] = Description
Selenium
# Out:
# Empty DataFrame
# Columns: [Exception_Name, Description]
# Index: []

# %% [markdown]
# # Q.4.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url = ("https://statisticstimes.com/")
driver.get(url)

# %%
# clicking on Economy button
driver.find_element(By.CLASS_NAME,'dropbtn').click()

# %%
# clicking on India
ind_search = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')

india = ind_search.get_attribute("href")
driver.get(india)
sleep(3)

# %%
# clicking on GDP of Indian Economy
try:
    GDP = driver.find_element(By.XPATH,'//a[class="ec"]').click()
    sleep(3)
except NoSuchElementException:
    GDP_capita = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[2]/a').click()

# %%
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP_billion = []

# scraping Rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
# scraping State
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("_")
    
# scraping GSDP at current price (19-20)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]"):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("_")
    
# scraping GSDP at current price (18-19)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]"):
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append("_")
    
# scraping Share (18-19)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("_")
    
# scraping GDP $ billion
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]"):
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append("_")
    
    
# creating DataFrame from the scraped data
GDP = pd.DataFrame({})
GDP['Rank'] = Rank
GDP['State'] = State
GDP['GSDP at current price (19-20)'] = GSDP1
GDP['GSDP at current price (18-19)'] = GSDP2
GDP['Share (18-19)'] = Share
GDP['GDP($ billion)'] = GDP_billion
GDP
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                        Goa                       520,030
# 1     2                     Sikkim                       487,201
# 2     3                      Delhi                       427,309
# 3     4                 Chandigarh                             -
# 4     5                    Haryana                       290,712
# ..  ...                        ...                           ...
# 61   29                    Manipur                        84,746
# 62   30                  Jharkhand                        79,873
# 63   31              Uttar Pradesh                        65,704
# 64   32                      Bihar                        46,664
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share (18-19) GDP($ billion)
# 0                        476,370          335%          7,029
# 1                        435,199          306%          6,421
# 2                        394,216          277%          5,817
# 3                        359,030          252%          5,297
# 4                        260,287          183%          3,840
# ..                           ...           ...            ...
# 61                        75,229        59.76%         53,930
# 62                        73,155        58.11%         57,863
# 63                        62,652        49.77%         44,618
# 64                        40,982        32.56%         31,287
# 65                             -             -              -
#
# [66 rows x 6 columns]

# %% [markdown]
# # Q.5.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url = ("https://github.com/")
driver.get(url)

# %%
# getting explore button and clicking on it
source = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/button').click()

# %%
# selecting trending option
trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
# creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

# fetching urls for each repository
repository = driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))
    
# scraping Repository title data
title = driver.find_elements(By.XPATH,"//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)
    
# scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(5)
    
    # scraping Repository Description data 
    try:
        desc = driver.find_element(By.XPATH,"//p[@class='f4 mt-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # scraping Contributors Count data
    try:
        contributor = driver.find_element(By.XPATH,"//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
    
    
    # scraping Languages used data
    try:
        for i in driver.find_elements(By.XPATH,"//ul[@class= 'list-style-none']//li//span[1]"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
        
# Data Framing
Github = pd.DataFrame({})
Github['Repository Title'] = repository_title
Github['Repository Description'] = Description
Github['Contributors Count'] = Contributors
Github['Language Used'] = Language
Github
# Out:
#                                      Repository Title Repository Description  \
# 0                  lkwq007 / stablediffusion-infinity                      -
# 1                         TheAlgorithms / C-Plus-Plus                      -
# 2                                      iced-rs / iced                      -
# 3                         sherlock-project / sherlock                      -
# 4                         freeCodeCamp / freeCodeCamp                      -
# 5                                       novuhq / novu                      -
# 6                                       github / docs                      -
# 7              AUTOMATIC1111 / stable-diffusion-webui                      -
# 8            firstcontributions / first-contributions                      -
# 9                        midudev / hacktoberfest-2022                      -
# 10                             CodeEditApp / CodeEdit                      -
# 11                                  ToolJet / ToolJet                      -
# 12                             HavocFramework / Havoc                      -
# 13                             stefanprodan / podinfo                      -
# 14   total-typescript / beginners-typescript-tutorial                      -
# 15                      fineanmol / Hacktoberfest2022                      -
# 16                  ossamamehmood / Hacktoberfest2022                      -
# 17            Aashu-Dubey / React-Native-UI-Templates                      -
# 18                                    yt-dlp / yt-dlp                      -
# 19                                   TryGhost / Ghost                      -
# 20                       mikeroyal / Steam-Deck-Guide                      -
# 21     developedbyed / react-portofolio-with-tailwind                      -
# 22                             TheAlgorithms / Python                      -
# 23  GoVanguard / Getting-into-InfoSec-and-Cybersec...                      -
# 24                              freqtrade / freqtrade                      -
#
#    Contributors Count                                      Language Used
# 0                   3  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 1                 280  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 2                 125  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 3                 171  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 4               4,549  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 5                 109  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 6               1,456  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 7                  89  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 8               3,557  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 9                  80  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 10                 71  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 11                214  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 12                  6  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 13                 35  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 14                 12  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 15                775  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 16                452  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 17                  -  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 18              1,023  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 19                413  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 20                  8  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 21                  -  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 22                842  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 23                  5  [Python, HTML, JavaScript, Jupyter Notebook, S...
# 24                239  [Python, HTML, JavaScript, Jupyter Notebook, S...

# %% [markdown]
# # Q.6.

# %%
url = ("https://www.billboard.com/")
driver.get(url)
sleep(1)

# %%
charts=driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a').click()

# %%
Song_Name = []
Artist_Name =[]
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# getting urls for top 100 songs
urls = driver.find_element(By.XPATH,"/html/body/div[4]/header/div/div[3]/div/nav/ul/li[1]/a")
page_url = urls.get_attribute("href")
driver.get(page_url)
sleep(4)

# scraping data of song names
for i in driver.find_elements(By.XPATH,"//span[@class='chart-element__information__song text--truncate color--primary']"):
    Song_Name.append(i.text)
    
# scraping data of artist names
for i in driver.find_elements(By.XPATH,"//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    Artist_Name.append(i.text)
    
# scraping data of last week ranks
for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--last']"):
    Last_week_rank.append(i.text)
    

# scraping data of peak ranks
for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    Peak_rank.append(i.text)       
    
    
# scraping data of weeks on board
for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--week']"):
    Weeks_on_board.append(i.text)
    
    
# creating dataframe for scraped data
billiboard = pd.DataFrame({})
billiboard['Name'] = Song_Name
billiboard['Artist'] = Artist_Name
billiboard['Last Week Rank'] = Last_week_rank
billiboard['Peak Rank'] = Peak_rank
billiboard['Weeks on board'] = Weeks_on_board
billiboard
# Out:
# Empty DataFrame
# Columns: [Name, Artist, Last Week Rank, Peak Rank, Weeks on board]
# Index: []

# %% [markdown]
# # Q.7.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url = ("https://www.naukri.com/")
driver.get(url)
sleep(3)

# %%
try:
    recruter = driver.find_element(By.XPATH,'//a[class="ec"]').click()
    
except NoSuchElementException:
     companies= driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div[2]/nav/ul/li[2]/a').click()

# %%
search = driver.find_element(By.XPATH,'//span[@class="nI-gNb-sb__placeholder"]').send_keys('Data Science')
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 search = driver.find_element(By.XPATH,'//span[@class="nI-gNb-sb__placeholder"]').send_keys('Data Science')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:223, in WebElement.send_keys(self, *value)
#     220             remote_files.append(self._upload(file))
#     221         value = '\n'.join(remote_files)
# --> 223 self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     224               {'text': "".join(keys_to_typing(value)),
#     225                'value': keys_to_typing(value)})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=106.0.5249.62)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x002DDF13+2219795]
# 	Ordinal0 [0x00272841+1779777]
# 	Ordinal0 [0x00184100+803072]
# 	Ordinal0 [0x001AE523+976163]
# 	Ordinal0 [0x001ADB93+973715]
# 	Ordinal0 [0x001CE7FC+1107964]
# 	Ordinal0 [0x001A94B4+955572]
# 	Ordinal0 [0x001CEA14+1108500]
# 	Ordinal0 [0x001DF192+1175954]
# 	Ordinal0 [0x001CE616+1107478]
# 	Ordinal0 [0x001A7F89+950153]
# 	Ordinal0 [0x001A8F56+954198]
# 	GetHandleVerifier [0x005D2CB2+3040210]
# 	GetHandleVerifier [0x005C2BB4+2974420]
# 	GetHandleVerifier [0x00376A0A+565546]
# 	GetHandleVerifier [0x00375680+560544]
# 	Ordinal0 [0x00279A5C+1808988]
# 	Ordinal0 [0x0027E3A8+1827752]
# 	Ordinal0 [0x0027E495+1827989]
# 	Ordinal0 [0x002880A4+1867940]
# 	BaseThreadInitThunk [0x76536739+25]
# 	RtlGetFullPathName_UEx [0x77408FD2+1218]
# 	RtlGetFullPathName_UEx [0x77408F9D+1165]
# 	(No symbol) [0x00000000]

# %%
btn = driver.find_element(By.XPATH,'//span[@class="ni-gnb-icn ni-gnb-icn-search"]').click()
time.sleep(3)

# %%
try :
    search.send_keys("Data Science")
    
except ElementNotInteractableException:
    pass
    search.send_keys("Data Scientist")
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
#       1 try :
# ----> 2     search.send_keys("Data Science")
#       4 except ElementNotInteractableException:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:223, in WebElement.send_keys(self, *value)
#     221         value = '\n'.join(remote_files)
# --> 223 self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     224               {'text': "".join(keys_to_typing(value)),
#     225                'value': keys_to_typing(value)})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=106.0.5249.62)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x011BDF13+2219795]
# 	Ordinal0 [0x01152841+1779777]
# 	Ordinal0 [0x01064100+803072]
# 	Ordinal0 [0x0108E523+976163]
# 	Ordinal0 [0x0108DB93+973715]
# 	Ordinal0 [0x010AE7FC+1107964]
# 	Ordinal0 [0x010894B4+955572]
# 	Ordinal0 [0x010AEA14+1108500]
# 	Ordinal0 [0x010BF192+1175954]
# 	Ordinal0 [0x010AE616+1107478]
# 	Ordinal0 [0x01087F89+950153]
# 	Ordinal0 [0x01088F56+954198]
# 	GetHandleVerifier [0x014B2CB2+3040210]
# 	GetHandleVerifier [0x014A2BB4+2974420]
# 	GetHandleVerifier [0x01256A0A+565546]
# 	GetHandleVerifier [0x01255680+560544]
# 	Ordinal0 [0x01159A5C+1808988]
# 	Ordinal0 [0x0115E3A8+1827752]
# 	Ordinal0 [0x0115E495+1827989]
# 	Ordinal0 [0x011680A4+1867940]
# 	BaseThreadInitThunk [0x76536739+25]
# 	RtlGetFullPathName_UEx [0x77408FD2+1218]
# 	RtlGetFullPathName_UEx [0x77408F9D+1165]
#
#
# During handling of the above exception, another exception occurred:
#
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
#       4 except ElementNotInteractableException:
#       5     pass
# ----> 6     search.send_keys("Data Scientist")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:223, in WebElement.send_keys(self, *value)
#     220             remote_files.append(self._upload(file))
#     221         value = '\n'.join(remote_files)
# --> 223 self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     224               {'text': "".join(keys_to_typing(value)),
#     225                'value': keys_to_typing(value)})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=106.0.5249.62)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x011BDF13+2219795]
# 	Ordinal0 [0x01152841+1779777]
# 	Ordinal0 [0x01064100+803072]
# 	Ordinal0 [0x0108E523+976163]
# 	Ordinal0 [0x0108DB93+973715]
# 	Ordinal0 [0x010AE7FC+1107964]
# 	Ordinal0 [0x010894B4+955572]
# 	Ordinal0 [0x010AEA14+1108500]
# 	Ordinal0 [0x010BF192+1175954]
# 	Ordinal0 [0x010AE616+1107478]
# 	Ordinal0 [0x01087F89+950153]
# 	Ordinal0 [0x01088F56+954198]
# 	GetHandleVerifier [0x014B2CB2+3040210]
# 	GetHandleVerifier [0x014A2BB4+2974420]
# 	GetHandleVerifier [0x01256A0A+565546]
# 	GetHandleVerifier [0x01255680+560544]
# 	Ordinal0 [0x01159A5C+1808988]
# 	Ordinal0 [0x0115E3A8+1827752]
# 	Ordinal0 [0x0115E495+1827989]
# 	Ordinal0 [0x011680A4+1867940]
# 	BaseThreadInitThunk [0x76536739+25]
# 	RtlGetFullPathName_UEx [0x77408FD2+1218]
# 	RtlGetFullPathName_UEx [0x77408F9D+1165]

# %% [markdown]
# # Q.8.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url = ("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/")
driver.get(url)
time.sleep(3)

# %%
# creating empty lists
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []


# scraping book names data
for i in driver.find_elements(By.XPATH,"//tbody//tr//td[2]"):
    Book_name.append(i.text)

    
# scraping author names data
for i in driver.find_elements(By.XPATH,"//tbody//tr//td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author_name.append(i.text)
    except NoSuchElementException:
        Author_name.append('-')
time.sleep(3)


# scraping data of volumes sold
for i in driver.find_elements(By.XPATH,"//tbody//tr//td[4]"):
    Volumes_sold.append(i.text)
    
    
# scraping data of publisher names
for i in driver.find_elements(By.XPATH,"//tbody//tr//td[5]"):
    Publisher.append(i.text)
    
    
# scraping  data of genre
for i in driver.find_elements(By.XPATH,"//tbody//tr//td[6]"):
    Genre.append(i.text)    
    
    
# creating dataframe for scraped data
Novels = pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # Q.9.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url = ("https://www.imdb.com/list/ls095964455/")
driver.get(url)

# %%
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# scraped data of Names
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)
    
    
# scraped data of Year span
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)
    
    
# scraped data of Genre
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)
    
    
# scraped data of Run time
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)
    
    
# scraped data of Ratings
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
    
# scraped data of Votes
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text) 
    
    
# creating dataframe for scraped data
TV_Series = pd.DataFrame({})
TV_Series['Name'] = Name
TV_Series['Year Span'] = Year_span
TV_Series['Genre'] = Genre
TV_Series['Run Time'] = Run_time
TV_Series['Ratings'] = Ratings
TV_Series['Votes'] = Votes
TV_Series
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,061,920
# 1    51 min     8.7  1,155,388
# 2    44 min     8.1    972,544
# 3    60 min     7.5    289,951
# 4    43 min     7.6    249,371
# ..      ...     ...        ...
# 95   42 min     7.4     49,698
# 96   50 min     7.8     60,759
# 97   42 min     8.1    195,561
# 98   45 min     7.1     41,159
# 99  572 min     8.6    238,241
#
# [100 rows x 6 columns]

# %% [markdown]
# # Q.10.

# %%
driver = webdriver.Chrome(r"C:\Users\Swati\OneDrive\Desktop\DataScience\chromedriver.exe")

# %%
url = (" https://archive.ics.uci.edu/")
driver.get(url)

# %%
viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
sleep(3)

# %%
view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
list_url = view_list.get_attribute("href")
driver.get(list_url)
sleep(3)

# %%
dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")

urls = []
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
# creating empty lists

Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    sleep(3)
    
    
    # scraping  Dataset name
    try:
        dataset_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    sleep(3)
    
    
    
    # scraping data type
    try:
        data_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    sleep(3)
    
    
    # scraping Task
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    sleep(3)
    
    
    
    # scraping Attribute type
    try:
        attribute_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    sleep(3)
    
    
    
    # scraping No of Instances
    try:
        instances = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    sleep(3)
    
    
    
    # scraping No of Arrtibutes
    try:
        attribute = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    sleep(3)
    
    
    # scraping Year
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    sleep(3)

# %%
# creating dataframe for scraped data
ML = pd.DataFrame({})
ML['Data_name'] = Dataset_name
ML['Data Type '] = Data_type
ML['Task '] = Task 
ML['Attribute Type '] = Attribute_type 
ML['No of Instance '] = No_of_instances
ML['No of Attributes '] = No_of_attributes 
ML['Year '] = Year 
ML
# Out:
#                                              Data_name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 617  Youtube cookery channels viewers comments in H...
# 618     YouTube Multiview Video Games Dataset Data Set
# 619                   YouTube Spam Collection Data Set
# 620                           Z-Alizadeh Sani Data Set
# 621                                       Zoo Data Set
#
#                     Data Type                        Task   \
# 0                 Multivariate              Classification
# 1             Sequential, Text      Regression, Clustering
# 2    Multivariate, Time-Series  Classification, Clustering
# 3                   Sequential  Classification, Regression
# 4                 Multivariate  Classification, Clustering
# ..                         ...                         ...
# 617         Multivariate, Text              Classification
# 618         Multivariate, Text  Classification, Clustering
# 619                       Text              Classification
# 620                          -              Classification
# 621               Multivariate              Classification
#
#           Attribute Type  No of Instance  No of Attributes  Year
# 0                    Real            7840                 5  2018
# 1                    Real          434874                 4  2013
# 2           Integer, Real            1984                 8  2019
# 3                    Real          158716                 4  2021
# 4                       -             232                16  2020
# ..                    ...             ...               ...   ...
# 617                     -            9800                 3  2019
# 618         Integer, Real          120000           1000000  2013
# 619                     -            1956                 5  2017
# 620         Integer, Real             303                56  2017
# 621  Categorical, Integer             101                17  1990
#
# [622 rows x 7 columns]
